# %% [markdown]
# #### ⭐Load Datasets and explore some useful informations⭐

# %%
#Loading Libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("countries-of-the-world.csv")
print(df.head())
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
mpg = pd.read_csv("mpg.csv")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
survey_data = pd.read_csv('young-people-survey-responses.csv', index_col='Unnamed: 0')
survey_data.head()
# Out:
#    Music  Techno  Movies  History  Mathematics  Pets  Spiders  Loneliness  \
# 0    5.0     1.0     5.0      1.0          3.0   4.0      1.0         3.0
# 1    4.0     1.0     5.0      1.0          5.0   5.0      1.0         2.0
# 2    5.0     1.0     5.0      1.0          5.0   5.0      1.0         5.0
# 3    5.0     2.0     5.0      4.0          4.0   1.0      5.0         5.0
# 4    5.0     2.0     5.0      3.0          2.0   1.0      1.0         3.0
#
#    Parents' advice   Internet usage  Finances   Age  Siblings  Gender  \
# 0              4.0  few hours a day       3.0  20.0       1.0  female
# 1              2.0  few hours a day       3.0  19.0       2.0  female
# 2              3.0  few hours a day       2.0  20.0       2.0  female
# 3              2.0  most of the day       2.0  22.0       1.0  female
# 4              3.0  few hours a day       4.0  20.0       1.0  female
#
#   Village - town
# 0        village
# 1           city
# 2           city
# 3           city
# ...

# %%
survey_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1010 entries, 0 to 1009
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Music            1007 non-null   float64
#  1   Techno           1003 non-null   float64
#  2   Movies           1004 non-null   float64
#  3   History          1008 non-null   float64
#  4   Mathematics      1007 non-null   float64
#  5   Pets             1006 non-null   float64
#  6   Spiders          1005 non-null   float64
#  7   Loneliness       1009 non-null   float64
#  8   Parents' advice  1008 non-null   float64
#  9   Internet usage   1010 non-null   object
#  10  Finances         1007 non-null   float64
#  11  Age              1003 non-null   float64
#  12  Siblings         1004 non-null   float64
#  13  Gender           1004 non-null   object
#  14  Village - town   1006 non-null   object
# dtypes: float64(12), object(3)
# memory usage: 126.2+ KB

# %% [markdown]
# #### ⭐Making a scatter plot with lists⭐
# Creat three lists of data from this dataset :

# %% [markdown]
# ###### gdp is a list that contains the value of GDP per country, expressed as dollars per person.
# ###### phones is a list of the number of mobile phones per 1,000 people in that country.
# ###### percent_literate is a list that contains the percent of each country's population that can read and write

# %%
gdp=df["GDP ($ per capita)"].tolist()
phones=df["Phones (per 1000)"].tolist()
percent_literate=df["Literacy (%)"].tolist()
region=df["Region"].tolist()

# %%
sns.scatterplot(x=gdp, y=phones)
plt.show()

# %%
# Change this scatter plot to have percent literate on the y-axis
sns.scatterplot(x=gdp, y=percent_literate)
plt.show()

# %%
# Create count plot with region on the y-axis
sns.countplot(y=region)
plt.show()

# %% [markdown]
# #### Hue and scatter plots :
# hue allows us to easily make subgroups within Seaborn plots. Let's try it out by exploring data from students in secondary school. We have a lot of information about each student like their age, where they live, their study habits and their extracurricular activities.
#
# For now, we'll look at the relationship between the number of absences they have in school and their final grade in the course, segmented by where the student lives (rural vs. urban area).

# %%
student_data=pd.read_csv("student-alcohol-consumption.csv", index_col="Unnamed: 0")
print(student_data.head())
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures schoolsup  \
# 0     GP   F   18     GT3       A     4     4           2         0       yes
# 1     GP   F   17     GT3       T     1     1           1         0        no
# 2     GP   F   15     LE3       T     1     1           1         3       yes
# 3     GP   F   15     GT3       T     4     2           1         0        no
# 4     GP   F   16     GT3       T     3     3           1         0        no
#
#    ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0  ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1  ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2  ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3  ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4  ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
#
# [5 rows x 29 columns]

# %%
# Create a scatter plot of absences vs. final grade
sns.scatterplot(x='absences',
           y='G3',
           data=student_data, hue='location')
plt.show()

# %%
#Make "Rural" appear before "Urban" in the plot legend
# Change the legend order in the scatter plot
sns.scatterplot(x="absences", y="G3", 
                data=student_data, 
                hue="location", hue_order=['Rural', 'Urban'])
plt.show()

# %% [markdown]
# #### ⭐Making a count plot with a DataFrame⭐

# %% [markdown]
# ###### we'll look at the responses to a survey sent out to young people. Our primary question here is: how many young people surveyed report being scared of spiders?
#
# ###### "I am afraid of spiders". Responses vary from 1 to 5, where 1 is "Strongly disagree" and 5 is "Strongly agree".

# %%
df1 = pd.read_csv("young-people-survey-responses.csv", index_col="Unnamed: 0")
print(df1.head())
# Out:
#    Music  Techno  Movies  History  Mathematics  Pets  Spiders  Loneliness  \
# 0    5.0     1.0     5.0      1.0          3.0   4.0      1.0         3.0
# 1    4.0     1.0     5.0      1.0          5.0   5.0      1.0         2.0
# 2    5.0     1.0     5.0      1.0          5.0   5.0      1.0         5.0
# 3    5.0     2.0     5.0      4.0          4.0   1.0      5.0         5.0
# 4    5.0     2.0     5.0      3.0          2.0   1.0      1.0         3.0
#
#    Parents' advice   Internet usage  Finances   Age  Siblings  Gender  \
# 0              4.0  few hours a day       3.0  20.0       1.0  female
# 1              2.0  few hours a day       3.0  19.0       2.0  female
# 2              3.0  few hours a day       2.0  20.0       2.0  female
# 3              2.0  most of the day       2.0  22.0       1.0  female
# 4              3.0  few hours a day       4.0  20.0       1.0  female
#
#   Village - town
# 0        village
# 1           city
# 2           city
# 3           city
# ...

# %%
# Create a count plot with "Spiders" on the x-axis
sns.countplot(x='Spiders', data=df1)
plt.show()

# %% [markdown]
# #### Hue and count plots

# %%
# Create a dictionary mapping subgroup values to colors
palette_colors = {"Rural": "green", "Urban": "blue"}

# Create a count plot of school with location subgroups
sns.countplot(x="school", data=student_data, hue="location", palette=palette_colors)
plt.show()

# %% [markdown]
# #### Try to use a new style "Black_style"

# %%
# Sample data
categories = ['Category A', 'Category B', 'Category C', 'Category D']
values = [15, 28, 12, 35]

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x=categories, y=values, palette="pastel")
plt.title("Sample Bar Plot")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# #### ⭐Visualizing Two Quantitative Variables⭐

# %%
# Change to use relplot() instead of scatterplot()
sns.relplot(x="absences", y="G3", 
                data=student_data, kind="scatter")
plt.show()

# %%
# Change to make subplots based on study time
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter", col="study_time")
plt.show()

# %%
# Change this scatter plot to arrange the plots in rows instead of columns
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter", 
            row="study_time")
plt.show()

# %% [markdown]
# ##### Creating two-factor subplots

# %%
# Create a scatter plot of G1 vs. G3
sns.relplot(x="G1", y="G3", data=student_data, kind="scatter")
plt.show()

# %%
# Adjust to add subplots based on school support
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"])
plt.show()

# %%
# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            row="famsup",
            col_order=["yes", "no"],
            row_order=["yes", "no"])
plt.show()

# %% [markdown]
# ##### Changing the size of scatter plot points

# %%
# Create scatter plot of horsepower vs. mpg
sns.relplot(x="horsepower",
            y="mpg",
        data=mpg,
        kind="scatter",
        size="cylinders")
plt.show()

# %%
# Create scatter plot of horsepower vs. mpg
sns.relplot(x="horsepower", y="mpg", 
            data=mpg, kind="scatter", 
            size="cylinders", 
            hue="cylinders")
plt.show()

# %%
# Create a scatter plot of acceleration vs. mpg
sns.relplot(x="acceleration",
            y="mpg",
            data=mpg,
            kind="scatter",
            hue="origin",
            style="origin")
plt.show()

# %%
# Create line plot
sns.relplot(x="model_year",
            y="mpg",
            data=mpg,
            kind="line")
plt.show()

# %%
# Make the shaded area show the standard deviation
sns.relplot(x="model_year", y="mpg",
            data=mpg, kind="line",
            ci="sd")
plt.show()
# Out:
# C:\Users\BAHRI\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
# Create line plot of model year vs. horsepower
sns.relplot(x="model_year", y="horsepower", data=mpg, kind='line', ci=None)
plt.show()
# Out:
# C:\Users\BAHRI\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
# Change to create subgroups for country of origin
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", style="origin",hue="origin",
            ci=None)
plt.show()
# Out:
# C:\Users\BAHRI\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
# Add markers and make each line have the same style
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None, style="origin", markers=True, dashes=False,
            hue="origin")
plt.show()
# Out:
# C:\Users\BAHRI\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# #### ⭐Visualizing a Categorical and a Quantitative Variable⭐

# %% [markdown]
# ###### "Count plot - Bar plot - Box plot"

# %%
# Create count plot of internet usage
sns.catplot(x="Internet usage", 
            data=survey_data,
            kind="count")
plt.show()

# %%
# Change the orientation of the plot
sns.catplot(y="Internet usage", data=survey_data,
            kind="count")
plt.show()

# %%
# Separate into column subplots based on age category
"""
First we Separate this plot into two side-by-side column subplots based on "Age Category", which separates respondents 
into those that are younger than 21 vs. 21 and older.
"""
survey_data["Age Category"] = np.where(survey_data["Age"] < 21, "younger than 21", "21 and older")

#Plotting the new column
sns.catplot(y="Internet usage", data=survey_data,
            kind="count", col="Age Category")
plt.show()

# %%
# Create a bar plot of interest in math, separated by gender
sns.catplot(x="Gender", y="Mathematics", data=survey_data, kind="bar")
plt.show()

# %%
# Create bar plot of average final grade in each study category
sns.catplot(x="study_time", y="G3", data=student_data, kind="bar")
plt.show()

# %%
# List of categories from lowest to highest
category_order = ["<2 hours", 
                  "2 to 5 hours", 
                  "5 to 10 hours", 
                  ">10 hours"]

# Rearrange the categories
sns.catplot(x="study_time", y="G3",
            data=student_data,
            kind="bar",
            order=category_order)
plt.show()

# %%
# List of categories from lowest to highest
category_order = ["<2 hours", 
                  "2 to 5 hours", 
                  "5 to 10 hours", 
                  ">10 hours"]

# Turn off the confidence intervals
sns.catplot(x="study_time", y="G3",
            data=student_data,
            kind="bar",
            order=category_order,
            ci=None)
plt.show()
# Out:
# C:\Users\BAHRI\AppData\Local\Temp\ipykernel_9348\3037771482.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x="study_time", y="G3",

# %%
# Specify the category ordering
study_time_order = ["<2 hours", "2 to 5 hours", 
                    "5 to 10 hours", ">10 hours"]

# Create a box plot and set the order of the categories
sns.catplot(x="study_time", y="G3", data=student_data, kind="box",order=study_time_order)
plt.show()

# %%
# Set the whiskers to 0.5 * IQR
sns.catplot(x="romantic", y="G3",
            data=student_data,
            kind="box", whis=0.5)
plt.show()

# %%
# Create a box plot with subgroups and omit the outliers
sns.catplot(x="internet", y="G3", data=student_data, kind="box", hue="location", sym="")
plt.show()

# %%
# Extend the whiskers to the 5th and 95th percentile
sns.catplot(x="romantic", y="G3",
            data=student_data,
            kind="box",
            whis=[5, 95])
plt.show()

# %%
# Set the whiskers at the min and max values
sns.catplot(x="romantic", y="G3",
            data=student_data,
            kind="box",
            whis=[0, 100])

plt.show()

# %% [markdown]
# ###### "Customizing point plots"

# %%
# Create a point plot of family relationship vs. absences
sns.catplot(x="famrel", y="absences", data=student_data, kind="point")
plt.show()

# %%
# Add caps to the confidence interval
sns.catplot(x="famrel", y="absences",
			data=student_data,
            kind="point", capsize=0.2)
        
plt.show()

# %%
# Remove the lines joining the points
sns.catplot(x="famrel", y="absences",
			data=student_data,
            kind="point",
            capsize=0.2, join=False)

plt.show()

# %% [markdown]
# ###### "Point plots with subgroups"

# %%
# Create a point plot that uses color to create subgroups
sns.catplot(x="romantic", y="absences", data=student_data, kind="point", hue="school")

plt.show()

# %%
# Turn off the confidence intervals for this plot
sns.catplot(x="romantic", y="absences",
			data=student_data,
            kind="point",
            hue="school", ci=None)

plt.show()
# Out:
# C:\Users\BAHRI\AppData\Local\Temp\ipykernel_9348\4286320221.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x="romantic", y="absences",

# %%
# Import median function from numpy
from numpy import median

# Plot the median number of absences instead of the mean
sns.catplot(x="romantic", y="absences",
			data=student_data,
            kind="point",
            hue="school",
            ci=None, estimator=median)

plt.show()
# Out:
# C:\Users\BAHRI\AppData\Local\Temp\ipykernel_9348\2341109927.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x="romantic", y="absences",

# %% [markdown]
# #### ⭐Customizing Plots⭐

# %%
# Set the context to "paper"
sns.set_context("paper")

# Create bar plot
sns.catplot(x="Siblings", y="Loneliness",
            data=survey_data, kind="bar")
plt.show()

# %%
# Change the context to "notebook"
sns.set_context("notebook")

# Create bar plot
sns.catplot(x="Siblings", y="Loneliness",
            data=survey_data, kind="bar")

plt.show()

# %%
# Change the context to "talk"
sns.set_context("talk")

# Create bar plot
sns.catplot(x="Siblings", y="Loneliness",
            data=survey_data, kind="bar")

plt.show()

# %%
# Change the context to "poster"
sns.set_context("poster")

# Create bar plot
sns.catplot(x="Siblings", y="Loneliness",
            data=survey_data, kind="bar")

plt.show()

# %%
# Set the style to "darkgrid"
sns.set_style("darkgrid")

# Set a custom color palette
custom_palette = ["#39A7D0", "#36ADA4"]
sns.set_palette(custom_palette)

# Create the box plot of age distribution by gender
sns.catplot(x="Gender", y="Age", 
            data=survey_data, kind="box")

plt.show()

# %%
# Create scatter plot
g = sns.relplot(x="weight", 
                y="horsepower", 
                data=mpg,
                kind="scatter")

# Identify plot type
type_of_g = type(g)

# Print type
print(type_of_g)
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %%
sns.set_context("talk")
# Create scatter plot
g = sns.relplot(x="weight", 
                y="horsepower", 
                data=mpg,
                kind="scatter")

# Add a title "Car Weight vs. Horsepower"
g.fig.suptitle("Car Weight vs. Horsepower")
plt.show()

# %%
# Create line plot
g = sns.lineplot(x="model_year", y="mpg", 
                 data=mpg,
                 hue="origin")

# Add a title "Average MPG Over Time"
g.set_title("Average MPG Over Time")

# Add x-axis and y-axis labels
g.set(xlabel="Car Model Year",
    ylabel="Average MPG")


# Show plot
plt.show()

# %%
# Create point plot
sns.catplot(x="origin", 
            y="acceleration", 
            data=mpg, 
            kind="point", 
            join=False, 
            capsize=0.1)

# Rotate x-tick labels
plt.xticks(rotation=90)
plt.show()

# %%
# Set palette to "Blues"
sns.set_palette("Blues")
sns.set_context("notebook")

# Adjust to add subgroups based on "Interested in Pets"
g = sns.catplot(x="Gender",
                y="Age", data=survey_data, 
                kind="box", hue="Pets")

# Set title to "Age of Those Interested in Pets vs. Not"
g.fig.suptitle("Age of Those Interested in Pets vs. Not")
plt.show()

# %%
# Set the figure style to "dark"
sns.set_style("dark")

# Adjust to add subplots per gender
g = sns.catplot(x="Village - town", y="Techno", 
                data=survey_data, kind="bar",
                col="Gender")

# Add title and axis labels
g.fig.suptitle("Percentage of Young People Who Like Techno", y=1.02)
g.set(xlabel="Location of Residence", 
       ylabel="% Who Like Techno")
plt.show()
